# %%
#assigment 1
var1=int(input("Enter the first number : "))
var2=int(input("Enter the second number :"))

sum=var1+var2
print("sum : ",sum)

product=var1*var2
print("Product :",product)

sub=var1-var2
print("sub :",sub)
# Out:
# Enter the first number : 5
# Enter the second number :3
# sum :  8
# Product 15
# sub 2

# %%
#assigment 2
import math
r=float(input("Enter the radius : "))
area = math.pi * r **2 
print("area :" ,area)
cir=2*math.pi*r
print("circumference :",cir)
# Out:
# Enter the radius : 4
# area : 50.26548245743669
# circumference : 25.132741228718345

# %%
#assigment 3
num1=float(input("first number : "))
num2=float(input("second number : "))
if (num1>num2):
  print("first num is greater")

elif(num1<num2):
  print("second num is greater" )
else:
  print("both are equal")
# Out:
# first number : 4
# second number : 6
# second num is greater

# %%
#assigment 4
num1=float(input("first number : "))
num2=float(input("second number : "))

if(num1>num2):
  sub=num1-num2
  print("sub",sub)
# Out:
# first number : 6
# second number : 2
# sub 4.0

# %%
#assigment 5
num =int(input("The number : "))
if num % 2==0:
  print("The number is even")
else:
  print("The number is odd")
# Out:
# The number : 6
# The number is even

# %%
#assigment 6
num=int(input("enter your number : "))
if num%2==0 or num%5==0 :
  print(num)
elif num%2==0 and num%5==0:
  print("num is multiple of 2 and 5")
else:
  print("not a multiple of 2 or 5")
# Out:
# enter your number : 20
# 20

# %%
#assigment 6
num=int(input("enter your number : "))
if num%2==0 or num%5==0 :
  print("num is multiple of 2 or 5")
else:
  print("not a multiple of 2 or 5")
# Out:
# enter your number : 20
# num is multiple of 2 or 5

# %%
#assigment 7

num=int(input("Enter a num" ))
if num % 2==0 and num%5!=0 or num%2!=0 and num%5==0:
  print(num)
else:
  print("Not a multipule we want")
# Out:
# Enter a num6
# 6

# %%
#assigment 8
num=int(input("enter your number : "))
if num%2==0 and num%5==0 :
  print(num)

else:
  print("not a multiple of 2 and 5")
# Out:
# enter your number : 6
# not a multiple of 2 or 5

# %%
#assigment 9
time = int(input())

seconds = time % (24 * 3600)
hour = time // 3600
time %= 3600
minutes = time // 60
time %= 60
print(time)
# Out:
# 10000
# 40

# %%
#assigment 10
hours = int(input("Enter worked hour: "))
salary = int()
extra_hours = int()
if hours<0:
  print("hours can't be negative")
elif hours>168:
  print("impossible to work more than 168 hours weekly")
elif hours in range (0,168):
  if hours<=40:
    salary=200*hours
    print(salary)
  elif hours>40:
    extra_hours=hours-40
    salary=8000 + extra_hours*300
    print(salary)
# Out:
# Enter worked hour: 100
# 26000

# %%
#11
S = int(input("Enter your value: "))

if( S < 100 ):
    L1 = 3000 - 125 **(S, 2)
    print ("L1:", L1)
else:
    L2 = 12000 / (4 + (S**2)/ 14900)
    print ("L2:", L2)
# Out:
# Enter your value: 120
# L2: 2416.2162162162163

# %%
#assigment 12
time = int(input("Enter a number: "))
if time >=4 and time <= 6:        
  print("Breakfast")    
elif time >=12 and time <= 13:        
  print("Lunch")    
elif time >=16 and time <= 17:        
  print("Snacks")    
elif time >=19 and time <= 20:        
  print("Dinner")    
elif time>=0 and time<24:          
  print("Patience is a virtue")
else:
  print("Wrong Time.")
# Out:
# Enter a number: 4
# Breakfast

# %%
#assigment 13
mark = int(input("Enter your Mark: "))
if mark < 0 or mark > 100:    
  print("Not a valid mark")
else:    
  if mark >= 0 and mark < 50:        
    print("F")    
  elif mark >=50 and mark <=59:        
    print("E")    
  elif mark >=60 and mark <=69:        
    print("D")    
  elif mark >=70 and mark <=79:        
    print("C")    
  elif mark >=80 and mark <=89:        
    print("B")    
  elif mark >= 90 and mark <= 100:        
    print("A")
# Out:
# Enter your Mark: 85
# B

# %%
#assigment 14
dis = int(input("enter the distance in seconds: "))
tim = int(input("enter your distance in meters: "))
distance= dis/1000
time= tim/3600
velocity = distance/time
print(velocity,"km/h")

if velocity< 60:
  print("Too slow.Need more changes")
elif 60<=velocity < 90:
  print("velocity is okay.The car is rady")
elif velocity>90:
  print("Too fast.Only a few changes should suffice")
# Out:
#   File "<ipython-input-2-1931c1d4dbda>", line 14
#     print("Too fast.Only a few changes should suffice"/n."me)
#                                                                ^
# SyntaxError: EOL while scanning string literal

# %%
#assigment 15
credit=int("Enter eligible for a waiver")
gpa=float(input("Enter your gpa: "))
if credit >=30:
  if gpa==4.0:
    print("The student is eligible for a waiver ")
  elif gpa<=4.0 and gpa>=3.99 :
    print("The student is eligible for a waiver of 100 percent.")
  elif gpa>=3.95 and gpa<=3.99 :
    print("The student is eligible for a waiver of 75 percent.")
  elif gpa>=3.90 and gpa<=3.94 :
    print("The student is eligible for a waiver of 50 percent.")
  elif gpa>=3.80 and gpa<=3.89 :
    print("The student is eligible for a waiver of 25 percent.")
else:
  print("not eligible")
# Out:
# Enter your gpa: 3.9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-65ae36331cc6> in <module>()
#       2 credit=("Enter eligible for a waiver")
#       3 gpa=float(input("Enter your gpa: "))
# ----> 4 if credit >=30:
#       5   if gpa==4.0:
#       6     print("The student is eligible for a waiver ")
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
#assigment 16
p = 5
2
q = 6
3
r = 9

sum = 0

if (p < 12):
 print(r + 2)

else:
 print(r + p)

if (q > 20):
 print(r + 19)

elif (q <= 6):
 print(q + 3)

else:
 print(p + q + r)

if (r > 15):
 print(r)

elif (r == 0):
 print(p + q)

else:
 print(p)

if (sum != 0):
 print(3)

else:
 print(sum + 32)

if (p>0 and r<10):
 print(p+r)
else:
 print(p-r)
# Out:
# 11
# 9
# 5
# 32
# 14

# %%
var1 = var2 = var3 = var4 = var5 = var6 = False
2
result1 = result2 = result3 = result4 = result5 = result6 = False
3
result7 = result8 = result9 = result10 = False
4
var1 = (not False or False) and True
5
var2 = var1 and True
6
var3 = False and not True
7
var4 = True
8
var5 = False
9
var6 = var3 and True
10
result1 = (var1 and var2) and ( 40 % 3 > 45) or (var5 and var6)
11
result2 = (var1 or var2) or (result1 and False)
12
result3 = (var1 and result1) or result2 or var5
13
result4 = (var1 or var2) or ((var3 and var1) and False)
14
result5 = (var1 and var2) and (result3 or var1)
15
result6 = ((var3 or not var2) and (result5)) or True
16
result7 = (var4 and result1) and ((result1 and False) or True)
17
result8 = ((var1 and result3) and (not var5 or var6)) and True
18
result9 = ((result2 and var2) or (not result7 and var1)) and not False
19
result10 = not (var1 and True)

print(result1,result2,result3,result4,result5,result6,result7,result8,result9,result10)
# Out:
# False True True True True True False True True False

# %%
var1 = False
2
var2 = False
3
var3 = False
4
var4 = False
5
var5 = False
6
var6 = False
7
result1 = False
8
result2 = False
9
result3 = False
10
result4 = False
11
result5 = False
12
result6 = False
13
result7 = False
14
result8 = False
15
result9 = False
16
result10 = False
17
var1 = ((not True) or True) and False
18
var2 = var1 and False
19
var3 = True and not False
20
var4 = False
21
var5 = True
22
var6 = var3 and False
23
result1 = (var1 and var2) and (40 % 3) > 45 or (var5 and var6)
24
result2 = (var1 or var2) or (result1 and False)
25
result3 = (var1 and result1) or result2 or var5
26
result4 = (var1 or var2) or ((var3 and var1) and False)
27
result5 = (var1 and var2) and (result3 or var1)
28
result6 = ((var3 or (not var2)) and (result5)) or True
29
result7 = (var4 and result1) and ((result1 and False) or True)
30
result8 = ((var1 and result3) and ((not var5) or var6)) and True
31
result9 = ((result2 and var2) or ((not result7) and var1)) and not False
32
result10 = not(var1 and True)
print(result1,result2,result3,result4,result5,result6,result7,result8,result9,result10)
# Out:
# False False True False False True False False False True

# %%
var1 = var2 = var3 = var4 = var5 = var6 = False
2
result1 = False
3
result2 = False
4
result3 = False
5
result4 = False
6
result5 = False
7
result6 = False
8
result7 = False
9
result8 = False
10
result9 = False
11
result10 = False
12
var1 = 4 > 3 - 1
13
var2 = var1 and False
14
var3 = True
15
var4 = False
16
var5 = True
17
var6 = var3 and False
18
result1 = (var1 or var2) and (8 * 10 > 45)
19
result2 = (var1 or var2) and (result1 and False)
20
result3 = (var1 and result1) or result2
21
result4 = (var1 or var2) or ((var3 and var1) and False)
22
result5 = (var1 and var2) and (result3 or var1)
23
result6 = ((var3 or var2) and not(result5)) or True
24
result7 = (var4 and result1) and ((result1 and False) or True)
25
result8 = ((var1 and result3) and (var5 or var6)) and True
26
result9 = ((result2 and var2) or (result7 and var1)) and False
27
result10 = not(var1 and True)
print(result1,result2,result3,result4,result5,result6,result7,result8,result9,result10)
# Out:
# True False True True False True False True False False

# %%
#20
n=int(input())
if n%2 !=0 and n%5!=0:
  print(n)
else:
  print("no")
# Out:
# 3
# 3

# %%
#21
n=int(input())
if n%2 !=0 or n%5!=0:
  print(n)
else:
  print("no")
# Out:
# 14
# 14

# %%
#22
canvas=120
tube=75
canvas_num=int(input())
tube_num=int(input())
total=canvas_num*canvas + tube_num*tube
print(total)
if total>=0 and total<=299:
  print("no discount")
elif  total >=300 and total<=499:
  print(total-10)
elif total>=500 and total<= 749:
  print(total-20)
elif total>=750 and total<= 999:
  print(total-50)
elif total>=100:
  print(total-150)
else:
  print("not valid")

# %%
#23
farenheit=int(input())
cel=int((farenheit-32)*0.56)
print("celcius",cel)
if cel<20:
  print("wenter")
elif cel>=20 and cel<=25:
  print("autume")
elif cel>25 and cel<30:
  print("spring")
elif cel>=30:
  print("summer")

# %%
#24
