# %%
#1
num=input()
for i in range(len(num)-1,-1,-1):
  print(num[i],end="")
# Out:
# cse110
# 011esc

# %%
n=input()
m=len(n)
for i in range (m-1,-1,-1):
  print(n[i],end="")
# Out:
# cse
# esc

# %%
#2
str1=input("enter a number ")
idx=int(input())
str2=""
str2=str1[idx::-1]
str2+=str1[idx+1]
print(str2)
# Out:
# enter a number 123456
# 4
# 543216

# %%
n=input()
m=""
for i in n:
  m=i+m
  print(m)
# Out:
# 12345
# 1
# 21
# 321
# 4321
# 54321

# %%
#3
num=input()
flag=True
for i in num:
  if i =="0" or i=="1":
    pass
  else:
    flag=False
    break
if(flag):
    print("Bynary")
else:
    print("not a Bynary")
# Out:
# 100100
# Bynary

# %%
n=input()
counter=0
for i in n:
  if i!="0" and i !="1":
    counter+=1
if counter==0:
  print("byna")
else:
  print("not")
# Out:
# 23
# not

# %%
#4
word = input()
num = len(word)

if(word[-2:] == "er"):
    word2 = word.replace("er","est")
    print(str2)
elif(num > 3 and word[-3:] == "est"):
    print(word)
elif(num > 3 ):
    print("{0}er".format(word))
elif(num < 4):
    print(word)
# Out:
# strong
# stronger

# %%
#4
word = input()
num = len(word)

if(word[-2:] == "er"):
    word2 = word.replace("er","est")
    print(str2)
elif(num > 3 and word[-3:] == "est"):
    print(word)
elif(num > 3 ):
    print((word)+"er")
elif(num < 4):
    print(word)
# Out:
# dream
# dreamer

# %%
w=input()
n=len(w)
if w[-2:]=="er":
  print(w.replace("er","est"))
elif n>3 and w[-3:]=="est":
  print(w)
elif n>3:
  w=w+"er"
  print(w)
elif n<4:
  print(w)
# Out:
# dreeamest
# dreeamest

# %%
#5
input = input()

for index in range(len(input)+1):
    print(input[:index])
# Out:
# kabir
#
# k
# ka
# kab
# kabi
# kabir

# %%
n=input()
s=" "
for i in n:
  s=s+i
  print(s)
# Out:
# canada
#  c
#  ca
#  can
#  cana
#  canad
#  canada

# %%
#6
a=input()
for i in a:
  print(i,":",ord(i))
# Out:
# tahmid
# t : 116
# a : 97
# h : 104
# m : 109
# i : 105
# d : 100

# %%
#7
a = input()

for i in a:
    n = ord(i)
    n += 1
    
    if(n > 122):
        n = 97
        
    m = chr(n)
    print(m)
# Out:
# abcd
# b
# c
# d
# e

# %%
#8
str1= input()

for ch in str1:
    if(str1.index(ch) % 2 != 0 ):
        print(ch.upper() ,end ="")
# Out:
# kabir
# AI

# %%
#8
s=input()
a=" "
b=" "
c=" "
for i in range(len(s)):
  if i % 2!=0:
    a=s[i]
    b=ord(a)
    c=chr(b-32)
    print(c,end="")
# Out:
# abcde
# BD

# %%
#9
str1=input()
std=str1[0]
for i in range(0,len(str1)):
  if std==str1[i]:
    pass
  else:
    print(str1[i],end="")
    std=str1[i]
# Out:
# aabbccdd
# bcd

# %%
#9
s=input()
p=""
for char in s:
    if char not in p:
        p=p+char
print(p)
# Out:
# aaaaaaa
# a

# %%
n=input()
p=""
for i in range(len(n)):
  if i < len(n)-1:
    if n[i] != n[i+1]:
      p=p+n[i]
    else:
      p=p+n[i]
       
  print(p)
# Out:
# AAAaaAAAaaAAaa
# A
# AA
# AAA
# AAAa
# AAAaa
# AAAaaA
# AAAaaAA
# AAAaaAAA
# AAAaaAAAa
# AAAaaAAAaa
# AAAaaAAAaaA
# AAAaaAAAaaAA
# AAAaaAAAaaAAa
# AAAaaAAAaaAAa

# %%
n=input()
m=len(n)
p=""
for i in range(m):
  if i < m-1:
    if x[i]!=x[i+1]:
      p=p+n[i]
  else:
    p=p+n[i]
  print(p)
# Out:
# AAABBBCDDECE
#
#
# A
# A
# A
# AB
# ABC
# ABCD
# ABCD
# ABCDE
# ABCDEC
# ABCDECE

# %%
#10
s = input()
n1 = 0
i1 = 0
while s[n1] != ',':
    n1 += 1
i2 = n1 + 2
n2 = len(s)

s1 = ''
while i1 < n1 and i2 < n2:
    s1 += s[i1] + s[i2]
    i1 += 1
    i2 += 1

if i1 < n1:
    s += s1[i1:n1]
else:
    s1 += s[i2:n2]

print(s1)
# Out:
# ABCD
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-5bc0aa612c0c> in <module>()
#       3 n1 = 0
#       4 i1 = 0
# ----> 5 while s[n1] != ',':
#       6     n1 += 1
#       7 i2 = n1 + 2
#
# IndexError: string index out of range

# %%
#11
i = 10

while(i >= -20):
  if(i < 0):
    test = " != "

    test = str(i//2) + test + str(int(i/2))

  else:

    test = " == "

    test = str(i//2) + test + str(int(i/2))
  print(test)
  i-=5
# Out:
# 5 == 5
# 2 == 2
# 0 == 0
# -3 != -2
# -5 != -5
# -8 != -7
# -10 != -10

# %%
#11
i = 10

while(i >= -20):
  if(i < 0):
    test = " != "

    test = str(i//2) + test + str(int(i/2))

  else:

    test = " == "

    test = str(i//2) + test + str(int(i/2))
  print(test)
  i-=1
# Out:
# 5 == 5
# 4 == 4
# 4 == 4
# 3 == 3
# 3 == 3
# 2 == 2
# 2 == 2
# 1 == 1
# 1 == 1
# 0 == 0
# 0 == 0
# -1 != 0
# -1 != -1
# -2 != -1
# -2 != -2
# -3 != -2
# -3 != -3
# -4 != -3
# -4 != -4
# -5 != -4
# -5 != -5
# -6 != -5
# -6 != -6
# -7 != -6
# -7 != -7
# -8 != -7
# -8 != -8
# -9 != -8
# -9 != -9
# -10 != -9
# -10 != -10

# %%
i= -13
test=str(i//2)
print(test)
# Out:
# -7

# %%
#12
test = ""

i = 0

j = 0

k = 15

test = "-->"

while i < 5:
  j = k - 1

  k -= 1

  while j > 10:
    test = str(i + j) + "-->" + test

    print(test)
    j-=1
  i+=1
# Out:
# 14-->-->
# 13-->14-->-->
# 12-->13-->14-->-->
# 11-->12-->13-->14-->-->
# 14-->11-->12-->13-->14-->-->
# 13-->14-->11-->12-->13-->14-->-->
# 12-->13-->14-->11-->12-->13-->14-->-->
# 14-->12-->13-->14-->11-->12-->13-->14-->-->
# 13-->14-->12-->13-->14-->11-->12-->13-->14-->-->
# 14-->13-->14-->12-->13-->14-->11-->12-->13-->14-->-->

# %%
#13
test = ""

i = 5
j = 0
k = 15
while i< 10:
  k-=1

  j = k
  while j > 10:
    if (j % 2) == 0:
      test = "<--"

      test = str(test) + str(i) + str(2) + "-->" + str(int(j / 2))

    else:

      test = "-->"
 
      test = "-->" + str(int(i / 2)) + str(test) + str(j)
    print(test)
    j-=1
  i+=1
# Out:
# <--52-->7
# -->2-->13
# <--52-->6
# -->2-->11
# -->3-->13
# <--62-->6
# -->3-->11
# <--72-->6
# -->3-->11
# -->4-->11

# %%
#14
test = ""
i = 5
j = 0
k = 15
while (i< 10):
  k-=1

  j = k

  while (j > 10 ):
    if j % 2 == 0:
      test = "<--"

      test = test + str( i) + '3' + "-->" + str(j // 3)

    else:

      test = "-->"

      test = "-->" + str((i // 3)) + test + str(j)
    print(test)
    j-=1
  i+=1
# Out:
# <--53-->4
# -->1-->13
# <--53-->4
# -->1-->11
# -->2-->13
# <--63-->4
# -->2-->11
# <--73-->4
# -->2-->11
# -->2-->11

# %%
i=0
j=0
k=15
test = '<--cat'
while i < 5:
  k -= 1

  j = k

  while j > 10:
    if j % 2 == 0:
      test += '-->'

      test = test + str(i) + str(j // 2)

    else:

      test += '<--'

      test = test + str(i // 2) + str(j)
    print(test)
    j-=1
  i+=1
# Out:
# <--cat-->07
# <--cat-->07<--013
# <--cat-->07<--013-->06
# <--cat-->07<--013-->06<--011
# <--cat-->07<--013-->06<--011<--013
# <--cat-->07<--013-->06<--011<--013-->16
# <--cat-->07<--013-->06<--011<--013-->16<--011
# <--cat-->07<--013-->06<--011<--013-->16<--011-->26
# <--cat-->07<--013-->06<--011<--013-->16<--011-->26<--111
# <--cat-->07<--013-->06<--011<--013-->16<--011-->26<--111<--111
