# %%
#1
list=[]
for i in range(5):
  a=int(input())
  list.append(a)

  print("Number in list",list)
# Out:
# 3
# Number in list [3]
# 4
# Number in list [3, 4]
# 5
# Number in list [3, 4, 5]
# 6
# Number in list [3, 4, 5, 6]
# 7
# Number in list [3, 4, 5, 6, 7]

# %%
#2
str1=input("enter a list")
str1= str1[1:len(str1)+1]
list_a=str1.split(",")



if len(list_a)>=4:
    list_a = list_a[2:-2]
    for i in range(len(list_a)):
      list_a[i]=int(list_a[i])
    print(list_a)  
else:
    print("not possible")
# Out:
# enter a list[1,2,3,4,5,6,7,8]
# [3, 4, 5, 6]

# %%
#3
user = []
for i in range(5):
    n = int(input())
    user.append(n)
   
for i in range(len(user)-1,-1,-1):
    print(user[i])
# Out:
# 1
# 2
# 3
# 4
# 5
# 5
# 4
# 3
# 2
# 1

# %%
#4
num=[]
ls=[1, 2, 3, 4, 5, 6, 7]
for i in range(len(ls)):
  
  a=ls[i]**2
  num.append(a)
print(num)
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
#5
mylist=[]
li=["hey", "there", "", "what's", "", "up", "", "?"]
for i in li:
  if i!="":
    user=mylist.append(i)
  else:
    continue
print(mylist)
# Out:
# ['hey', 'there', "what's", 'up', '?']

# %%
#6
temp=""
a=[]
lst="7, 13, 2, 10, 6, -11, 0"
for i in temp:
  
  if i != ",":
    temp+=i
  else:
    a.append(temp)
print(a)
max=0
for i in a:
  if i >max:
    max=i
print(max)
print(a.index(max))
# Out:
# []
# 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-9e3753f2c2cb> in <module>()
#      15     max=i
#      16 print(max)
# ---> 17 print(a.index(max))
#
# ValueError: 0 is not in list

# %%
s=input()
new=[int(i) for i in s[1:-1].split(",")]
max_num=new[0]
index=0
for x in range(1,len(new)-1):
  if new[x]>max_num:
    max_num=new[x]
    index=x
print(new)
print("largest number  in the list :",max_num,"index: ",index)
# Out:
# [7,2,10,13,4,5,6]
# [7, 2, 10, 13, 4, 5, 6]
# largest number  in the list : 13 index:  3

# %%
s=input()
new=[int(i) for i in s[1:-1].split(",")]
max_num=new[0]
min_num=new[0]
index=0
for x in range(1,len(new)-1):
  if new[x]>max_num:
    max_num=new[x]
    index=x
  elif new[x]<min_num:
    min_num=new[x]
    index=x
print(new)
print("largest number  in the list :",max_num,"index:",index ,"and", "smallest valu:",min_num,"index:",index)
# Out:
# [7,2,10,13,4,5,6]
# [7, 2, 10, 13, 4, 5, 6]
# largest number  in the list : 13 index: 3 and smallest valu: 2 index: 3

# %%
#7
list_1 = [int(count) for count in input("List_One = ")[1:-1].split(",")]
list_2 = [int(count) for count in input("List_Two = ")[1:-1].split(",")]

list_1[-1:]=list_2
print(list_1)
# Out:
# List_One = [1,4,7,5]
# List_Two = [6,1,39]
# [1, 4, 7, 6, 1, 39]

# %%
#7
list_one = [1,2,3,4,5]
list_two = [6,7,8,9,10]

res = list(set(list_one[:-1]+list_two))

print("Output for the above two list: ", res)
# Out:
# Output for the above two list:  [1, 2, 3, 4, 6, 7, 8, 9, 10]

# %%
#7
list_one = [1,2,3,4,5]
list_two = [6,7,8,9,10]

x=list_one[:-1]+list_two
print(x)
# Out:
# [1, 2, 3, 4, 6, 7, 8, 9, 10]

# %%
#8
list_one=[1,2,3,4,5,6,7,8,9]
list_two=[10,11,12,-13,-14,-15,-16]

even_list=[]

for i in list_one:
    if i%2==0:  
        even_list.append(i)

for i in list_two:
    if i%2==0:  
        even_list.append(i)
                
print(even_list)
# Out:
# [2, 4, 6, 8, 10, 12, -14, -16]

# %%
#11
list_one : [1, 4, 3, 2, 5]
list_two : [8, 7, 6, 9]

flag = False
for num in list_one:
    if num in list_two:
        flag = True
        break
print(flag)
# Out:
# False

# %%
#17
s=input()
new=[int(i) for i in s[1:-1].split(",")]
max_num=new[0]
min_num=new[0]
index=0
for x in range(1,len(new)-1):
  if new[x]>max_num:
    max_num=new[x]
    index=x
  elif new[x]<min_num:
    min_num=new[x]
    index=x
print(new)
print("largest number  in the list :",max_num,"index:",index ,"and", "smallest valu:",min_num,"index:",index)
# Out:
# [7, 13, -5, 10, 6]
# [7, 13, -5, 10, 6]
# largest number  in the list : 13 index: 2 and smallest valu: -5 index: 2

# %%
#18
list_1 = [item for item in input().replace(" ","").split(",")]
list_2 = [item for item in input().replace(" ","").split(",")]

print([item for item in list_1 if item in list_2])
# Out:
# A,B,C,D
# C,B,D,E
# ['B', 'C', 'D']

# %%
li1=input()
li2=input()
for i in li1:
   if i in li2:
     li1.replace(" ","").split(",")
     li2.replace(" ","").split(",")
print(i)
# Out:
# A,B,C,D
# B,C,D,E
# A
# ,
# B
# ,
# C
# ,
# D
